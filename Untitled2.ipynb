# %%
a=1/0
print(a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=1/0
#       2 print(a)
#
# ZeroDivisionError: division by zero

# %%
a=waqar
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=waqar
#       2 print(a)
#
# NameError: name 'waqar' is not defined

# %%
a=int(input('name'))
print(a)
# Out:
# name waqar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a=int(input('name'))
#       2 print(a)
#
# ValueError: invalid literal for int() with base 10: 'waqar'

# %%
a=[10,20,30]
a[40]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 a=[10,20,30]
# ----> 2 a[40]
#
# IndexError: list index out of range

# %%
# try         # try ke ander code me galti
# except       # tb ye chlega
# else         #agar try successfully work kriya 
# finally     # e to chliya hi chliye
# Out:
#   Cell In[10], line 1
#     try         # try ke ander code me galti
#                 ^
# SyntaxError: expected ':'

# %%
a=[12,34,543,34]
a[20]
name='waqar'
print(name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 a=[12,34,543,34]
# ----> 2 a[20]
#       3 name='waqar'
#       4 print(name)
#
# IndexError: list index out of range

# %%
try:
    a=[21,4,23]
    a[20]
    name=('waqar')
    print(name)
    
except:
    age=18
    if age>=18:
        print('can vote')
# Out:
# can vote

# %%
name=('waqar')
print(name)
a=[21,4,23]
a[20]
# Out:
# waqar
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 4
#       2 print(name)
#       3 a=[21,4,23]
# ----> 4 a[20]
#
# IndexError: list index out of range

# %%
a=[21,4,23]
a[20]
name=('waqar')
print(name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 a=[21,4,23]
# ----> 2 a[20]
#       3 name=('waqar')
#       4 print(name)
#
# IndexError: list index out of range

# %%
try:
    name=('waqar')
    print(name)
    a=[21,4,23]
    print(a[20])
except:
    print('done')
else:
    print('kaam hogya')
finally:
    print('ye chlega hi chlega')
# Out:
# waqar
# done
# ye chlega hi chlega

# %%
try:
    x = int(input("Enter number: "))
except:
    print("Number sahi daalo")
else:
    print("Sab sahi chala 👍")
finally:
    print("Program khatam ho gaya")
# Out:
# Enter number:  u
# Number sahi daalo
# Program khatam ho gaya

# %%
try:
    num = int(input("Enter number: "))

except ValueError:
    print("Galat input 😅")

else:
    print("Correct number:", num)

finally:
    print("Thanks for using program 🙌")
u
# Out:
# Enter number:  i
# Galat input 😅
# Thanks for using program 🙌

# %%
try:
    a=1/0
except Exception as e:
    print('ye error name hai',e)
# Out:
# ye error name hai division by zero

# %%
try:
    a=[21,23,4,35,4,6]
    a[20]
except Exception as e:
    print('ye error name hai',e)
# Out:
# ye error name hai list index out of range

# %%
try:
    a=[21,23,4,35,4,6]
    a[20]
except Exception as e :
    print('ye error name hai',e)
# Out:
# ye error name hai list index out of range

# %%
try:
    name=int(input('name'))
    print(name)
except Exception as e:
    print('ye rha error',e)
# Out:
# name waqar
# ye rha error invalid literal for int() with base 10: 'waqar'

# %%
name=int(input('name'))
print(name)
# Out:
# name waqar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 name=int(input('name'))
#       2 print(name)
#
# ValueError: invalid literal for int() with base 10: 'waqar'

# %%
if x == 5:
    print(x)

# %%
name={'name':'waqar',
     'age':}
print(name)
# Out:
#   Cell In[58], line 2
#     'age':}
#          ^
# SyntaxError: expression expected after dictionary key and ':'

# %%
try:
    name={'name':'waqar',
     'age':32}
    print(name)
    
except:
    print('done')
# Out:
# {'name': 'waqar', 'age': 32}

# %%
try:
    d = {'name': 'waqar', 'age': 25}
    print(d['city'])

except Exception as e:
    print('done',e)
# Out:
# done 'city'

# %%
d = {'name': 'waqar', 'age': 25}
print(d['city'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 2
#       1 d = {'name': 'waqar', 'age': 25}
# ----> 2 print(d['city'])
#
# KeyError: 'city'

# %%
try:
    a=1/0
except Exception as e:
    print('done',e)
# Out:
# done division by zero

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    a=[14,6]
    a[7]
except Exception as e:
    print('done',e)
# Out:
# done list index out of range

# %%
a=[14,6]
a[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 2
#       1 a=[14,6]
# ----> 2 a[7]
#
# IndexError: list index out of range

# %%
try:
    d = {'name': 'waqar', 'age': 25}
    print(d['city'])

except Exception as e:
    print("Error type:", type(e).__name__)
    print("Message:", e)
# Out:
# Error type: KeyError
# Message: 'city'

# %%
try:
    a=[14,6]
    a[7]
except Exception as e:
    print('done',e)
# Out:
# done list index out of range

# %%
try:
    a=[14,6]
    a[7]
except Exception as e:
    print('ye Class ka naam',type(e).__name__,'aur error ka naam hai ',e)
# Out:
# ye Class ka naam IndexError aur error ka naam hai  list index out of range
